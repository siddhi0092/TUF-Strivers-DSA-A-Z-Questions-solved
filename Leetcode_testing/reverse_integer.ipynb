# %%
# x = int(input("Enter a Number"))
x = 20
y = str(x)
# num = []
# while x>0:
#     num = x % 10
print(len(y))
# Out:
# 2

# %%
x = int(input("Enter a Number"))
if x<0:
    sliced = str(abs(x))[::-1]
    print(f"-{sliced}")
else:
    sliced = str(x)[::-1]
    print(sliced)
# Out:
# -123

# %%
s = int(input("Enter a number"))   
if s> 2**31:
    rounded = 2**31
    print(rounded)
elif s < -2**31:
    rounded = -2**31
    print(rounded)
elif s < 0:
    y = str(abs(s))
    x = int("-" + y)
    print(x)

else:
    y = str(abs(s))
    print(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 s = int(input("Enter a number"))
#       2 if s> 2**31:
#       3     rounded = 2**31
#
# ValueError: invalid literal for int() with base 10: '1   234'

# %%
nums1 = [1,2]
nums2 = [3,4]
nums3 = sorted(nums1 + nums2)
print(nums3)
mid = len(nums3) // 2
print(mid)
print(nums3[mid])
mideven = (nums3[mid] + nums3[mid -1]) / 2
print(mideven)
# Out:
# [1, 2, 3, 4]
# 2
# 3
# 2.5

# %%
print(58%5)
# Out:
# 3

# %%
print(3%5)
# Out:
# 3
